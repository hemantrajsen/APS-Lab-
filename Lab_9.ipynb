# %% [markdown]
# <a href="https://colab.research.google.com/github/hemantrajsen/APS-Lab-/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
# Predefined Input:
graph1 = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph1, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
# Modified program for user input graph with dictionary structure.
def input_to_dict():
  n = int(input("Enter the number of Edges in a graph: "))
  result = {}

  for _ in range(n):
    u = input("Enter source node: ")
    v = input("Enter destination node: ")
    value = int(input("Enter Value: "))

    if u not in result:
      result[u]= {}

    if v not in result:
      result[v] = {}

    result[u][v] = value #Add the edges

  return result

graph = input_to_dict()
print(graph)
# Out:
# Enter the number of Edges in a graph: 10
# Enter source node: A
# Enter destination node: B
# Enter Value: 4
# Enter source node: A
# Enter destination node: C
# Enter Value: 2
# Enter source node: B
# Enter destination node: A
# Enter Value: 4
# Enter source node: B
# Enter destination node: C
# Enter Value: 5
# Enter source node: B
# Enter destination node: D
# Enter Value: 10
# Enter source node: C
# Enter destination node: A
# Enter Value: 2
# Enter source node: C
# Enter destination node: B
# Enter Value: 5
# Enter source node: C
# Enter destination node: D
# Enter Value: 3
# Enter source node: D
# Enter destination node: B
# Enter Value: 10
# Enter source node: D
# Enter destination node: C
# Enter Value: 3
# {'A': {'B': 4, 'C': 2}, 'B': {'A': 4, 'C': 5, 'D': 10}, 'C': {'A': 2, 'B': 5, 'D': 3}, 'D': {'B': 10, 'C': 3}}

# %%
result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %%
# Modified program for user input graph with dictionary structure and with 2 more nodes added:

if 'E' not in graph: graph['E'] = {}
if 'F' not in graph: graph['F'] = {}

graph['D']['E'] = 1
graph['E']['D'] = 1
graph['C']['F'] = 7
graph['F']['C'] = 7
graph['B']['F'] = 6
graph['F']['B'] = 6

print(graph)
# Out:
# {'A': {'B': 4, 'C': 2}, 'B': {'A': 4, 'C': 5, 'D': 10, 'F': 6}, 'C': {'A': 2, 'B': 5, 'D': 3, 'F': 7}, 'D': {'B': 10, 'C': 3, 'E': 1}, 'E': {'D': 1}, 'F': {'C': 7, 'B': 6}}

# %%
result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5
# Distance from A to E = 6
# Distance from A to F = 9
